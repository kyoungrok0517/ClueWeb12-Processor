# %%
from blaze import Data
from odo import odo
from pandas import DataFrame

# %%
class FACC1Query(object):
    def __init__(self, uri='postgresql://postgres:Rudfhr88!@server.kyoungrok.com/facc1::clueweb12_00'):
        self.uri = uri
        self.facc1 = Data(self.uri)
        
    def get_entities(self, trec_id):
        df = odo(self.facc1[self.facc1.trec_id == trec_id], DataFrame)
        return [tuple(r) for r in df.to_records(index=False)]

# %%
q = FACC1Query()

# %%
q.get_entities('clueweb12-0010wb-69-01585')
# Out:
# [('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Sudan',
#   4659,
#   4664,
#   0.99483600000000005,
#   0.001057,
#   '/m/06tw8'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Sudan',
#   6643,
#   6648,
#   0.99483600000000005,
#   0.001057,
#   '/m/06tw8'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Sudan',
#   26331,
#   26336,
#   0.99483600000000005,
#   0.001057,
#   '/m/06tw8'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Sudan',
#   26407,
#   26412,
#   0.99483600000000005,
#   0.001057,
#   '/m/06tw8'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Sudan',
#   29688,
#   29693,
#   0.99483600000000005,
#   0.001057,
#   '/m/06tw8'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Sudan',
#   46428,
#   46433,
#   0.99483600000000005,
#   0.001057,
#   '/m/06tw8'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Sudan',
#   46928,
#   46933,
#   0.99483600000000005,
#   0.001057,
#   '/m/06tw8'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Sudan',
#   47519,
#   47524,
#   0.99483600000000005,
#   0.001057,
#   '/m/06tw8'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Sudan',
#   51980,
#   51985,
#   0.99483600000000005,
#   0.001057,
#   '/m/06tw8'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Sudan',
#   61235,
#   61240,
#   0.99483600000000005,
#   0.001057,
#   '/m/06tw8'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Sudan',
#   64383,
#   64388,
#   0.99483600000000005,
#   0.001057,
#   '/m/06tw8'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Sudan',
#   65409,
#   65414,
#   0.99483600000000005,
#   0.001057,
#   '/m/06tw8'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Sudan',
#   66919,
#   66924,
#   0.99483600000000005,
#   0.001057,
#   '/m/06tw8'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Sudan',
#   66996,
#   67001,
#   0.99483600000000005,
#   0.001057,
#   '/m/06tw8'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Sudan',
#   69768,
#   69773,
#   0.99483600000000005,
#   0.001057,
#   '/m/06tw8'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Sudanese',
#   46987,
#   46995,
#   0.99483600000000005,
#   0.001057,
#   '/m/06tw8'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Sudanese',
#   61510,
#   61518,
#   0.99483600000000005,
#   0.001057,
#   '/m/06tw8'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Sudanese',
#   64499,
#   64507,
#   0.99483600000000005,
#   0.001057,
#   '/m/06tw8'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Sudanese',
#   66779,
#   66787,
#   0.99483600000000005,
#   0.001057,
#   '/m/06tw8'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Islamist',
#   6596,
#   6604,
#   0.56624200000000002,
#   0.00059699999999999998,
#   '/m/0flw86'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Egyptian',
#   6852,
#   6860,
#   0.98280199999999995,
#   0.00050199999999999995,
#   '/m/02k54'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Egyptian',
#   6909,
#   6917,
#   0.98280199999999995,
#   0.00050199999999999995,
#   '/m/02k54'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Arab',
#   6865,
#   6869,
#   0.99577499999999997,
#   0.00045300000000000001,
#   '/m/0xff'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Arab',
#   6922,
#   6926,
#   0.99577499999999997,
#   0.00045300000000000001,
#   '/m/0xff'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Arab',
#   60280,
#   60284,
#   0.99577499999999997,
#   0.00045300000000000001,
#   '/m/0xff'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Arab',
#   61470,
#   61474,
#   0.99577499999999997,
#   0.00045300000000000001,
#   '/m/0xff'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Arab',
#   61972,
#   61976,
#   0.99577499999999997,
#   0.00045300000000000001,
#   '/m/0xff'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Arab',
#   66071,
#   66075,
#   0.99577499999999997,
#   0.00045300000000000001,
#   '/m/0xff'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Arabs',
#   61931,
#   61936,
#   0.99577499999999997,
#   0.00045300000000000001,
#   '/m/0xff'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Arabs',
#   65922,
#   65927,
#   0.99577499999999997,
#   0.00045300000000000001,
#   '/m/0xff'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Arabs',
#   66340,
#   66345,
#   0.99577499999999997,
#   0.00045300000000000001,
#   '/m/0xff'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'US Declaration of Independence',
#   18254,
#   18284,
#   1.0,
#   1.2e-05,
#   '/m/07v5q'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Darfur',
#   22439,
#   22445,
#   0.77483900000000006,
#   0.000173,
#   '/m/02vtml'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Darfur',
#   46400,
#   46406,
#   0.77483900000000006,
#   0.000173,
#   '/m/02vtml'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Darfur',
#   47211,
#   47217,
#   0.77483900000000006,
#   0.000173,
#   '/m/02vtml'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Darfur',
#   60657,
#   60663,
#   0.77483900000000006,
#   0.000173,
#   '/m/02vtml'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Darfur',
#   60728,
#   60734,
#   0.77483900000000006,
#   0.000173,
#   '/m/02vtml'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Darfur',
#   61167,
#   61173,
#   0.77483900000000006,
#   0.000173,
#   '/m/02vtml'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Darfur',
#   61539,
#   61545,
#   0.77483900000000006,
#   0.000173,
#   '/m/02vtml'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Darfur',
#   62231,
#   62237,
#   0.77483900000000006,
#   0.000173,
#   '/m/02vtml'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Darfur',
#   62390,
#   62396,
#   0.77483900000000006,
#   0.000173,
#   '/m/02vtml'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Darfur',
#   64209,
#   64215,
#   0.77483900000000006,
#   0.000173,
#   '/m/02vtml'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Darfur',
#   65820,
#   65826,
#   0.77483900000000006,
#   0.000173,
#   '/m/02vtml'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Darfur',
#   66029,
#   66035,
#   0.77483900000000006,
#   0.000173,
#   '/m/02vtml'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Darfur',
#   66705,
#   66711,
#   0.77483900000000006,
#   0.000173,
#   '/m/02vtml'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Darfur',
#   67085,
#   67091,
#   0.77483900000000006,
#   0.000173,
#   '/m/02vtml'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Darfur',
#   67554,
#   67560,
#   0.77483900000000006,
#   0.000173,
#   '/m/02vtml'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Darfur',
#   67734,
#   67740,
#   0.77483900000000006,
#   0.000173,
#   '/m/02vtml'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Darfur',
#   67831,
#   67837,
#   0.77483900000000006,
#   0.000173,
#   '/m/02vtml'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Darfur',
#   68367,
#   68373,
#   0.77483900000000006,
#   0.000173,
#   '/m/02vtml'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Darfur',
#   68628,
#   68634,
#   0.77483900000000006,
#   0.000173,
#   '/m/02vtml'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Darfur',
#   68931,
#   68937,
#   0.77483900000000006,
#   0.000173,
#   '/m/02vtml'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Darfur',
#   69269,
#   69275,
#   0.77483900000000006,
#   0.000173,
#   '/m/02vtml'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Africa',
#   25758,
#   25764,
#   0.99997100000000005,
#   5.1999999999999997e-05,
#   '/m/06qtn'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Africa',
#   62483,
#   62489,
#   0.99997100000000005,
#   5.1999999999999997e-05,
#   '/m/06qtn'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Africa',
#   62674,
#   62680,
#   0.99997100000000005,
#   5.1999999999999997e-05,
#   '/m/06qtn'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'sub-Saharan Africa',
#   67854,
#   67872,
#   0.99997100000000005,
#   5.1999999999999997e-05,
#   '/m/06qtn'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Africa',
#   68020,
#   68026,
#   0.99997100000000005,
#   5.1999999999999997e-05,
#   '/m/06qtn'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Africa',
#   68148,
#   68154,
#   0.99997100000000005,
#   5.1999999999999997e-05,
#   '/m/06qtn'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Africa',
#   68484,
#   68490,
#   0.99997100000000005,
#   5.1999999999999997e-05,
#   '/m/06qtn'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Europe',
#   25766,
#   25772,
#   0.93492500000000001,
#   0.0012899999999999999,
#   '/m/02j9z'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'America',
#   25778,
#   25785,
#   0.75785499999999995,
#   0.0063029999999999996,
#   '/m/09c7w0'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'US',
#   63612,
#   63616,
#   0.75785499999999995,
#   0.0063029999999999996,
#   '/m/09c7w0'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'US',
#   66715,
#   66719,
#   0.75785499999999995,
#   0.0063029999999999996,
#   '/m/09c7w0'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Oxfam',
#   26323,
#   26328,
#   0.99999099999999996,
#   4.1999999999999998e-05,
#   '/m/01gqgz'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Oxfam',
#   26378,
#   26383,
#   0.99999099999999996,
#   4.1999999999999998e-05,
#   '/m/01gqgz'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'United Nations Refugee Agency',
#   26762,
#   26791,
#   1.0,
#   0.00027700000000000001,
#   '/m/07vqq'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'High Commissioner for Refugees',
#   65033,
#   65063,
#   1.0,
#   0.00027700000000000001,
#   '/m/07vqq'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'UNICEF',
#   26796,
#   26802,
#   0.99987099999999995,
#   0.00018000000000000001,
#   '/m/0fxc0'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'New York',
#   28068,
#   28076,
#   0.72599999999999998,
#   0.00097300000000000002,
#   '/m/02_286'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'New York',
#   28179,
#   28187,
#   0.72599999999999998,
#   0.00097300000000000002,
#   '/m/02_286'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Texas',
#   46460,
#   46465,
#   0.91137199999999996,
#   0.00032699999999999998,
#   '/m/07b_l'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'China',
#   51094,
#   51099,
#   0.98989799999999994,
#   0.0012719999999999999,
#   '/m/0d05w3'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'China',
#   67491,
#   67496,
#   0.98989799999999994,
#   0.0012719999999999999,
#   '/m/0d05w3'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Kofi Annan',
#   51133,
#   51143,
#   0.99950600000000001,
#   6.6000000000000005e-05,
#   '/m/0498f'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'UN',
#   51128,
#   51130,
#   0.995861,
#   0.001322,
#   '/m/07t65'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'UN',
#   61314,
#   61318,
#   0.995861,
#   0.001322,
#   '/m/07t65'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'UN',
#   62495,
#   62499,
#   0.995861,
#   0.001322,
#   '/m/07t65'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'UN',
#   65028,
#   65032,
#   0.995861,
#   0.001322,
#   '/m/07t65'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'UN',
#   66853,
#   66857,
#   0.995861,
#   0.001322,
#   '/m/07t65'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'UN',
#   66959,
#   66963,
#   0.995861,
#   0.001322,
#   '/m/07t65'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'UN',
#   67154,
#   67158,
#   0.995861,
#   0.001322,
#   '/m/07t65'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Berkman Center',
#   51873,
#   51887,
#   1.0,
#   9.9999999999999995e-07,
#   '/m/05l86r'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Harvard Law School',
#   51891,
#   51909,
#   1.0,
#   2.0000000000000002e-05,
#   '/m/014zws'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Daily',
#   52151,
#   52156,
#   0.93440000000000001,
#   0.00092699999999999998,
#   '/m/05jnl'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Janjaweed',
#   60306,
#   60315,
#   1.0,
#   0.000112,
#   '/m/032nxq'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Janjaweed',
#   61475,
#   61484,
#   1.0,
#   0.000112,
#   '/m/032nxq'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Janjaweed',
#   65435,
#   65444,
#   1.0,
#   0.000112,
#   '/m/032nxq'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Janjaweed',
#   66461,
#   66470,
#   1.0,
#   0.000112,
#   '/m/032nxq'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Janjaweed',
#   69452,
#   69461,
#   1.0,
#   0.000112,
#   '/m/032nxq'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Janjaweed',
#   69649,
#   69658,
#   1.0,
#   0.000112,
#   '/m/032nxq'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Chad',
#   60621,
#   60625,
#   0.99673900000000004,
#   0.00064400000000000004,
#   '/m/01p1b'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Chad',
#   64406,
#   64410,
#   0.99673900000000004,
#   0.00064400000000000004,
#   '/m/01p1b'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Chad',
#   64484,
#   64488,
#   0.99673900000000004,
#   0.00064400000000000004,
#   '/m/01p1b'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Chad',
#   65082,
#   65086,
#   0.99673900000000004,
#   0.00064400000000000004,
#   '/m/01p1b'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Chad',
#   65374,
#   65378,
#   0.99673900000000004,
#   0.00064400000000000004,
#   '/m/01p1b'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Chad',
#   69546,
#   69550,
#   0.99673900000000004,
#   0.00064400000000000004,
#   '/m/01p1b'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Iriba',
#   60582,
#   60587,
#   1.0,
#   4.6999999999999997e-05,
#   '/m/0cw5gn'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'CARE',
#   61021,
#   61025,
#   0.49267499999999997,
#   6.0999999999999999e-05,
#   '/m/01kqfj'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Sahara',
#   61217,
#   61223,
#   0.94286999999999999,
#   3.3000000000000003e-05,
#   '/m/01w1vt'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Sahara',
#   61742,
#   61748,
#   0.94286999999999999,
#   3.3000000000000003e-05,
#   '/m/01w1vt'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Sahara',
#   62029,
#   62035,
#   0.94286999999999999,
#   3.3000000000000003e-05,
#   '/m/01w1vt'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Sahara',
#   62591,
#   62597,
#   0.94286999999999999,
#   3.3000000000000003e-05,
#   '/m/01w1vt'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Africans',
#   61554,
#   61562,
#   0.99362200000000001,
#   0.000745,
#   '/m/0dg3n1'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Africans',
#   62550,
#   62558,
#   0.99362200000000001,
#   0.000745,
#   '/m/0dg3n1'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'African',
#   61981,
#   61988,
#   0.99362200000000001,
#   0.000745,
#   '/m/0dg3n1'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'African',
#   64327,
#   64334,
#   0.99362200000000001,
#   0.000745,
#   '/m/0dg3n1'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Sahel',
#   61717,
#   61722,
#   0.98881600000000003,
#   2.1999999999999999e-05,
#   '/m/0l5_l'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'National Center for Atmospheric Research',
#   62178,
#   62218,
#   1.0,
#   3.0000000000000001e-06,
#   '/m/0bcl51'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Somalia',
#   62789,
#   62796,
#   0.99936599999999998,
#   0.00030400000000000002,
#   '/m/06tgw'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Robert Mugabe',
#   62927,
#   62940,
#   0.99960000000000004,
#   6.2000000000000003e-05,
#   '/m/0bsfy'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Zimbabwe',
#   62880,
#   62888,
#   0.95041900000000001,
#   0.00033300000000000002,
#   '/m/088q4'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Rwanda',
#   63271,
#   63277,
#   0.98246800000000001,
#   0.00017799999999999999,
#   '/m/06dfg'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Bush Administration',
#   63409,
#   63428,
#   0.98285199999999995,
#   2.3e-05,
#   '/m/0193q3'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Bush Administration',
#   67398,
#   67417,
#   0.98285199999999995,
#   2.3e-05,
#   '/m/0193q3'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'CNA Corporation',
#   63677,
#   63692,
#   1.0,
#   3.0000000000000001e-06,
#   '/m/030x2h'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Margaret Beckett',
#   63830,
#   63846,
#   1.0,
#   4.6999999999999997e-05,
#   '/m/01grn7'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Beckett',
#   63984,
#   63991,
#   1.0,
#   4.6999999999999997e-05,
#   '/m/01grn7'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'British',
#   63804,
#   63811,
#   0.91011200000000003,
#   0.001604,
#   '/m/07ssc'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'UN Security Council',
#   63920,
#   63941,
#   0.99954500000000002,
#   0.00036200000000000002,
#   '/m/07vnr'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Security Council',
#   67452,
#   67468,
#   0.99954500000000002,
#   0.00036200000000000002,
#   '/m/07vnr'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Central African Republic',
#   64419,
#   64443,
#   0.99999700000000002,
#   0.00045600000000000003,
#   '/m/01nyl'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Guereda',
#   64460,
#   64467,
#   1.0,
#   3.1999999999999999e-05,
#   '/m/0cw5hc'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'International Medical Corps',
#   64596,
#   64623,
#   1.0,
#   3.9999999999999998e-06,
#   '/m/03h4n81'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Khartoum',
#   66565,
#   66573,
#   0.88188699999999998,
#   0.00021699999999999999,
#   '/m/04d_m'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Khartoum',
#   67093,
#   67101,
#   0.88188699999999998,
#   0.00021699999999999999,
#   '/m/04d_m'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'African Union',
#   67199,
#   67212,
#   1.0,
#   0.000232,
#   '/m/0gkjy'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Washington',
#   68241,
#   68251,
#   0.68029200000000001,
#   0.00050000000000000001,
#   '/m/0rh6k'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Asia',
#   68535,
#   68539,
#   0.96761299999999995,
#   0.00034900000000000003,
#   '/m/0j0k'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Adam',
#   69143,
#   69147,
#   0.56374299999999999,
#   9.9999999999999995e-07,
#   '/m/09_c5v'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Adam',
#   69172,
#   69176,
#   0.56374299999999999,
#   9.9999999999999995e-07,
#   '/m/09_c5v'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Adam',
#   69382,
#   69386,
#   0.56374299999999999,
#   9.9999999999999995e-07,
#   '/m/09_c5v'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Adam',
#   69592,
#   69596,
#   0.56374299999999999,
#   9.9999999999999995e-07,
#   '/m/09_c5v'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Adam',
#   69911,
#   69915,
#   0.56374299999999999,
#   9.9999999999999995e-07,
#   '/m/09_c5v'),
#  ('clueweb12-0010wb-69-01585',
#   'UTF-8',
#   'Médecins Sans Frontières',
#   69331,
#   69357,
#   1.0,
#   6.4999999999999994e-05,
#   '/m/054p6')]
